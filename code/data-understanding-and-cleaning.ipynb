# %% [markdown]
#  <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<***Data understanding and cleaning.***>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
#import the required libraries 
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
#loading the data sets
df_business = pd.read_csv("/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv")
df_education = pd.read_csv("/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/education_data.csv")
df_entertainment = pd.read_csv("/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/entertainment_data.csv")
df_sports = pd.read_csv("/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/sports_data.csv")
df_technology = pd.read_csv("/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv")

# %%
#The size of the data set
print('business: ',df_business.shape)
print('education: ',df_education.shape)
print('entertainment: ',df_entertainment.shape)
print('sports: ',df_sports.shape)
print('technology: ',df_technology.shape)
# Out:
# business:  (2000, 5)
# education:  (2000, 5)
# entertainment:  (2000, 5)
# sports:  (2000, 5)
# technology:  (2000, 5)

# %%
#merge the datasets 
df = pd.concat([df_business,df_education,df_entertainment,df_sports,df_technology])

# %%
#jumble the data rows
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
df.head(6)
# Out:
#                                            headlines  \
# 0  Mohammed Shami likely to miss 2 Tests against ...
# 1  Athiya Shetty is ‘superstitious’ when KL Rahul...
# 2  Hindustan Unilever profit rises 8% in June qua...
# 3  Vijayakanth (1952-2023): Tamil Nadu loses its ...
# 4  Aamir Khan’s daughter Ira Khan reacts to husba...
# 5  ‘These kinds of surfaces are not good for Test...
#
#                                          description  \
# 0  Mohammad Shami has not started bowling post hi...
# 1  In a recent chat, KL Rahul opened up about the...
# 2  IT major Infosys' net profit in the June quart...
# 3  Actor-politician Vijayakanth breathed his last...
# 4  Ira Khan and Nupur Shikhare tied the knot on W...
# 5  India were all out for 109 after Matthew Kuhne...
#
#                                              content  \
# 0  Fast bowler Mohammed Shami is likely to miss t...
# 1  Indian wicketkeeper-batsman KL Rahul credits h...
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# headlines      0
# description    0
# content        0
# url            0
# category       0
# INSTRUCTION    0
# RESPONSE       0
# dtype: int64

# %%
#making instruction and response statement formats
df['INSTRUCTION'] = df['headlines'].copy()
df['RESPONSE'] = df['headlines'].copy()
for i in range(df.shape[0]):
    df['INSTRUCTION'][i] = f'The headline is "{df.headlines[i]}" with description "{df.description[i]}" and with content as "{df.content[i]}".'
for i in range(df.shape[0]):
    df['RESPONSE'][i] = f'The category is {df.category[i]} from the given details.'

# %%
df.head()
# Out:
#                                            headlines  \
# 0  Mohammed Shami likely to miss 2 Tests against ...
# 1  Athiya Shetty is ‘superstitious’ when KL Rahul...
# 2  Hindustan Unilever profit rises 8% in June qua...
# 3  Vijayakanth (1952-2023): Tamil Nadu loses its ...
# 4  Aamir Khan’s daughter Ira Khan reacts to husba...
#
#                                          description  \
# 0  Mohammad Shami has not started bowling post hi...
# 1  In a recent chat, KL Rahul opened up about the...
# 2  IT major Infosys' net profit in the June quart...
# 3  Actor-politician Vijayakanth breathed his last...
# 4  Ira Khan and Nupur Shikhare tied the knot on W...
#
#                                              content  \
# 0  Fast bowler Mohammed Shami is likely to miss t...
# 1  Indian wicketkeeper-batsman KL Rahul credits h...
# 2  Infosys on Thursday reported a lower-than-expe...
# 3  Tamil actor and politician Vijayakanth passed ...
# ...

# %%
#Let us observe the brief information of the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   headlines    10000 non-null  object
#  1   description  10000 non-null  object
#  2   content      10000 non-null  object
#  3   url          10000 non-null  object
#  4   category     10000 non-null  object
#  5   INSTRUCTION  10000 non-null  object
#  6   RESPONSE     10000 non-null  object
# dtypes: object(7)
# memory usage: 547.0+ KB

# %%
#sample instructions and responses
print(df.INSTRUCTION[0])
print("--------------------------")
print(df.RESPONSE[0])
# Out:
# The headline is "Mohammed Shami likely to miss 2 Tests against England; Suryakumar Yadav to undergo hernia surgery" with description "Mohammad Shami has not started bowling post his ankle injury; Suryakumar Yadav will need upto nine weeks post hernia operation" and with content as "Fast bowler Mohammed Shami is likely to miss the first two Test matches against England starting from January 25 as he hasn’t resumed bowling post his ankle injury. In another development, World’s No.1 ranked T20 batsman Suryakumar Yadav’s return to cricket could take longer as it is learnt that he is suffering from hernia and needs surgery. Yadav is expected to be completely fit by the time of the IPL. .
# ...

# %%
print(df.INSTRUCTION[1])
print("--------------------------")
print(df.RESPONSE[1])
# Out:
# The headline is "Athiya Shetty is ‘superstitious’ when KL Rahul is playing, cricketer says she was ‘more frustrated and angry’ than him when he was injured" with description "In a recent chat, KL Rahul opened up about the superstition Athiya Shetty has, just like her father Suniel Shetty, when he is playing." and with content as "Indian wicketkeeper-batsman KL Rahul credits his wife and Bollywood actor, Athiya Shetty for keeping him motivated to become a better version of himself. In a recent chat, the cricketer opened up about the superstition she has, just like her father Suneil Shetty, when he is playing. He also revealed how Athiya reacted on his injury which happened when he was playing an IPL match. The cricketer’s tendon ‘ripped apart’ from his quadricep and he had to go under the knife to recover.
# ...

# %%
#split the data into train and test
train_data = df.iloc[:8000,:]
test_data = df.iloc[8000:,:].reset_index(drop=True)

# %%
#train data size
train_data.shape
# Out:
# (8000, 7)

# %%
#test data size
test_data.shape
# Out:
# (2000, 7)

# %%
#save the files for next process

# %%
df.to_excel('source_data.xlsx', index=False)

# %%
train_data.to_excel('train_data.xlsx', index=False)

# %%
test_data.to_excel('test_data.xlsx', index=False)
